# %%
print("Hello world")
# Out:
# Hello world

# %%
name = "Mamatha"
age = 28
height = 5.3
is_student = True

print("Name:", name)
print("Age:" ,age)
print("Height:" ,height)
print("Is student:" ,is_student)
# Out:
# Name: Mamatha
# Age: 28
# Height: 5.3
# Is student: True

# %%
boolean = False
print(f"Boolean = {boolean}")

name = "Mamatha"
print("Name:",name,"boolean",boolean)
print(f"Name = {name} boolean ={boolean}")
# Out:
# Boolean = False
# Name: Mamatha boolean False
# Name = Mamatha boolean =False

# %%
#-int ,float,str
std_count = 50
avg_percentage = 90.5
passed_out = "2026"

print("Type of std_count:",type(std_count))
print("Type of avg_percentage:",type(avg_percentage))
print("Type of passed_out:",type(passed_out))
# Out:
# Type of std_count: <class 'int'>
# Type of avg_percentage: <class 'float'>
# Type of passed_out: <class 'str'>

# %%
first_name = 'Gentyala'
last_name = "Mamatha"
print(first_name,last_name)
print(type(first_name))

user = """I want to learn python AI and Ml>
         Could you please help me."""
print(user)
# Out:
# Gentyala Mamatha
# <class 'str'>
# I want to learn python AI and Ml>
#          Could you please help me.

# %%
is_submited = True
its_approved = False
has_rejected = True
print("IS submited",is_submited)
print("Type:",type(has_rejected))
# Out:
# IS submited True
# Type: <class 'bool'>

# %%
value = [35,3.15,"welcome",True,None,"111"]

for v in value:
    print(f" {repr(v):10}  ->  {type(v).__name__}")
# Out:
#  35          ->  int
#  3.15        ->  float
#  'welcome'   ->  str
#  True        ->  bool
#  None        ->  NoneType
#  '111'       ->  str

# %%
x = "10"
print(x, type(x).__name__)
print
# Out:
# 10 str
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
x = int("23")
y = int(60.3)
z = int(True)
a = str("abc")
m = float(38)
b = 500
c = float(b)


print(x, type(x).__name__)
print(y, type(y).__name__)
print(z, type(z).__name__)
print(a, type(a).__name__)
print(m, type(m))
print(c, type(c))
print(float(b))
# Out:
# 23 int
# 60 int
# 1 int
# abc str
# 38.0 <class 'float'>
# 500.0 <class 'float'>
# 500.0

# %%
a = int("15")
b = float(10)

print(a, type(a))
print(b, type(b))
# Out:
# 15 <class 'int'>
# 10.0 <class 'float'>

# %%
score = 23
message = "your score is:" +str(score)
print(message)
print(bool(0))
print(bool("mamatha"))
print(bool(123))
print(bool(None))
# Out:
# your score is:23
# False
# True
# True
# False

# %%
result = "Age: " + str(25)
print(result)
# Out:
# Age: 25

# %%
#exercise 1:

std_name = "Gayathri"
std_age = 28
std_gpa = 98.5
is_enrolled = True
grad_year = 2026

print(f" Student: {std_name} {std_age} {std_gpa} {is_enrolled} {grad_year}")
# Out:
#  Student: Gayathri 28 98.5 True 2026

# %%
#Exercise 2
values = [100, 100.0, "100", True, None, 0, "", "True"]
print(type(values))
# Out:
# <class 'list'>

# %%
#Exercise 3
a = int("50")
a+= 10
print(a)
b = float(7)
c = bool(0)
d = int(3.99)
print(b)
print(c)
print(d)
# Out:
# 60
# 7.0
# False
# 3

# %%
days = 100
weeks = days//7
remaining_days = days%7
print(f"{days} days = {weeks} weeks and {remaining_days} days")
# Out:
# 100 days = 14 weeks and 2 days

# %%
num = 20
if num % 2 == 0:
    print(f"{num} is Even")
else:
    print(f"{num} is Odd")

# %%
std_height = 5.2
short = 4.8
tall =5.5

if std_height <short:
    print('short')
elif short <std_height:
    print('medium')
else:
    print('tall')
